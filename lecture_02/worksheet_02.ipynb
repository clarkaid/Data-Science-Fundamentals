# %% [markdown]
# # Worksheet 02
#
# Name:  Aidan Clark
#
# UID: U01817265
#
# ### Topics
#
# - Effective Programming
#
# ### Effective Programming
#
# a) What is a drawback of the top down approach?

# %% [markdown]
# Because you write pseudocode first and then implement helper functions, you often cannot run/test your code until you've implemented all the functions.

# %% [markdown]
# b) What is a drawback of the bottom up approach?

# %% [markdown]
# Because you write all of the functions first, it can be hard to decide exactly which functions you'll ultimately need, which may lead to you implementing more functions than necessary.

# %% [markdown]
# c) What are 3 things you can do to have a better debugging experience?

# %% [markdown]
# First, don't panic and don't try to find the quickest fix possible. Next, actually read the error and determine where it is. Lastly, reread and trace through your code to try to reproduce the error

# %% [markdown]
# d) (Optional) Follow along with the live coding. You can write your code here:

# %%
class Board:

    def __init__(self):
        self.board = [["-" for _ in range(8) ] for _ in range(8)]

    def __repr__(self):
        res = ""
        for row in range(len(self.board)):
            for col in range(len(self.board[row])):
                res += self.board[row][col]
                res += " "
            res += "\n"

        return res
    
    def set_queen_at(self, row, col):
        self.board[row][col] = "Q"

    def unset_queen_on_row(self,row):
        self.board[row] = ["-" for _ in range(8)]

    def find_solution(self):
        row = 0
        col = 0

        while row < 8:
            #We are searching for a solution
            if self.is_valid_move(row, col):
                self.set_queen_at(row,col)
                row += 1
                col = 0
            else:
                col += 1
                if col >= 8:
                    # We weren't able to place a queen on this row. We need to backtrack.
                    col = self.get_queen_on_row(row - 1)
                    col += 1
                    row -= 1

        #We have found a solution
        print("Found a solution: ")
        print(self)

    
test = Board()
print(test)
test.set_queen_at(0,0)
print(test)
# Out:
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
#
# Q - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -

# %% [markdown]
# ## Exercise
#
# This exercise will use the [Titanic dataset](https://www.kaggle.com/c/titanic/data) (https://www.kaggle.com/c/titanic/data). Download the file named `train.csv` and place it in the same folder as this notebook.
#
# The goal of this exercise is to practice using [pandas](https://pypi.org/project/pandas/) methods. If your:
#
# 1. code is taking a long time to run
# 2. code involves for loops or while loops
# 3. code spans multiple lines
#
# look through the pandas documentation for alternatives. This [cheat sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf) may come in handy.
#
# a) Complete the code below to read in a filepath to the `train.csv` and returns the DataFrame.

# %%
import pandas as pd

df = pd.read_csv("train.csv")
df.describe()
# Out:
# C:\Users\aclar\AppData\Local\Temp\ipykernel_34064\295688908.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# b) Complete the code so it returns the number of rows that have at least one empty column value

# %%
print("there are " +  str(df[(df.isnull().sum(axis=1)) != 0].shape[0]) + " rows with at least one empty value")
# Out:
# there are 708 rows with at least one empty value

# %% [markdown]
# c) Complete the code below to remove all columns with more than 200 NaN values

# %%
df = df.dropna(axis = 1, thresh = (df.shape[0] - 200))
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# d) Complete the code below to replaces `male` with 0 and `female` with 1

# %%
df['Sex'] = df['Sex'].replace(to_replace = ["male", "female"], value = [0,1])
df.head()
# Out:
# C:\Users\aclar\AppData\Local\Temp\ipykernel_34064\3778438569.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Sex'] = df['Sex'].replace(to_replace = ["male", "female"], value = [0,1])
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %% [markdown]
# e) Complete the code below to add four columns `First Name`, `Middle Name`, `Last Name`, and `Title` corresponding to the value in the `name` column.
#
# For example: `Braund, Mr. Owen Harris` would be:
#
# |First Name | Middle Name | Last Name | Title |
# |-----------|-------------|-----------|-------|
# | Owen      |  Harris     |  Braund   | Mr    |
#
# Anything not clearly one of the above 4 categories can be ignored.

# %%
df[['First Name', 'Middle Name', 'Last Name', 'Title']] = df['Name'].str.replace(",|\.", "", regex = True).str.split(n = 4, expand = True).drop(4, axis=1).iloc[:, [2,3,0,1]]
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\aclar\AppData\Local\Temp\ipykernel_34064\2141849146.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df[['First Name', 'Middle Name', 'Last Name', 'Title']] = df['Name'].str.replace(",|\.", "", regex = True).str.split(n = 4, expand = True).drop(4, axis=1).iloc[:, [2,3,0,1]]
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Embarked First Name Middle Name  Last Name Title
# 0         A/5 21171   7.2500        S       Owen      Harris     Braund    Mr
# 1          PC 17599  71.2833        C       John     Bradley    Cumings   Mrs
# 2  STON/O2. 3101282   7.9250        S      Laina        None  Heikkinen  Miss
# 3            113803  53.1000        S    Jacques       Heath   Futrelle   Mrs
# 4            373450   8.0500        S    William       Henry      Allen    Mr

# %% [markdown]
# f) Complete the code below to replace all missing ages with the average age

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Embarked First Name Middle Name  Last Name Title
# 0         A/5 21171   7.2500        S       Owen      Harris     Braund    Mr
# 1          PC 17599  71.2833        C       John     Bradley    Cumings   Mrs
# 2  STON/O2. 3101282   7.9250        S      Laina        None  Heikkinen  Miss
# 3            113803  53.1000        S    Jacques       Heath   Futrelle   Mrs
# 4            373450   8.0500        S    William       Henry      Allen    Mr

# %% [markdown]
# g) Plot a bar chart of the average age of those that survived and did not survive. Briefly comment on what you observe.

# %%
df.groupby("Survived")['Age'].mean().plot(kind = "bar", title = "Ages of People on Titanic", xlabel = "Didn't Survive vs Survived", ylabel = "Average Age")
# Out:
# <Axes: title={'center': 'Ages of People on Titanic'}, xlabel="Didn't Survive vs Survived", ylabel='Average Age'>

# %% [markdown]
# It appears that the average age of those who did not survive is slightly higher than that of those who did survive. The people who survived the Titanic tended to be younger.
